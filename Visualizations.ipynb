# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
moviedf= pd.read_csv("Resources/full_table_rotten_analysis.csv")
moviedf.head(50)
# Out:
#                      rotten_tomatoes_link  \
# 0                               m/0814255
# 1                               m/0878835
# 2                                    m/10
# 3                  m/1000013-12_angry_men
# 4   m/1000079-20000_leagues_under_the_sea
# 5                              m/10000_bc
# 6                      m/1000121-39_steps
# 7                   m/1000123-310_to_yuma
# 8                       m/10002008-charly
# 9                          m/tatsumi_2011
# 10              m/1000204-abraham_lincoln
# 11                  m/10002114-dark_water
# 12                      m/1000224-accused
# 13                   m/10002516-lost_city
# 14              m/10002519-breaking_point
# 15                    m/1000253-adams_rib
# 16      m/10002635-bridge_of_san_luis_rey
# 17                     m/10002673-prowler
# 18                    m/10003276-criminal
# 19     m/1000334-adventures_of_mark_twain
# 20                   m/10003437-deep_blue
# 21     m/1000355-adventures_of_robin_hood
# 22                    m/10003876-man_hunt
# 23                    m/10003925-dead_end
# 24                       m/10004069-whore
# 25          m/10004209-tristan_and_isolde
# 26                   m/10004226-wild_side
# 27              m/10004288-running_scared
# 28          m/10004352-going_the_distance
# 29                 m/10004504-ultraviolet
# 30           m/10004635-home_of_the_brave
# 31                      m/10004659-arthur
# 32                 m/10004684-malevolence
# 33                     m/10004697-eternal
# 34            m/10004835-farewell_to_arms
# 35               m/10004890-narrow_margin
# 36                     m/10004925-matador
# 37                       m/10005057-smile
# 38                    m/10005104-intruder
# 39                 m/10005178-saint_ralph
# 40                  m/10005403-the_baxter
# 41                m/10005499-oliver_twist
# 42                        m/1000560-alamo
# 43                           m/10005755-g
# 44          m/1000580-alexander_the_great
# 45                        m/1000581-alfie
# 46           m/10005819-10005819-neverwas
# 47           m/10006007-the_second_chance
# 48                   m/10006057-moonlight
# 49                       m/1000617-aliens
#
#                                           movie_title  \
# 0   Percy Jackson & the Olympians: The Lightning T...
# 1                                         Please Give
# 2                                                  10
# 3                     12 Angry Men (Twelve Angry Men)
# 4                        20,000 Leagues Under The Sea
# 5                                         10,000 B.C.
# 6                                        The 39 Steps
# 7                                        3:10 to Yuma
# 8                           Charly (A Heartbeat Away)
# 9                                             Tatsumi
# 10                                    Abraham Lincoln
# 11                                         Dark Water
# 12                                        The Accused
# 13                                      The Lost City
# 14                                 The Breaking Point
# 15                                         Adam's Rib
# 16                         The Bridge of San Luis Rey
# 17                      The Prowler (Cost of Living )
# 18                                           Criminal
# 19                       The Adventures of Mark Twain
# 20                                          Deep Blue
# 21                       The Adventures of Robin Hood
# 22                                           Man Hunt
# 23                                           Dead End
# 24                                              Whore
# 25                                   Tristan & Isolde
# 26                                          Wild Side
# 27                                     Running Scared
# 28                                 Going the Distance
# 29                                        Ultraviolet
# 30                                  Home of the Brave
# 31  Arthur and the Invisibles (Arthur and the Mini...
# 32                                        Malevolence
# 33                                            Eternal
# 34                                 A Farewell To Arms
# 35                                  The Narrow Margin
# 36                                        The Matador
# 37                                              Smile
# 38                            The Intruder (L'Intrus)
# 39                                        Saint Ralph
# 40                                         The Baxter
# 41                                       Oliver Twist
# 42                                          The Alamo
# 43                                                  G
# 44                                Alexander the Great
# 45                                              Alfie
# 46                                           Neverwas
# 47                                  The Second Chance
# 48                                          Moonlight
# 49                                             Aliens
#
#                                            movie_info content_rating  \
# 0   Always trouble-prone, the life of teenager Per...             PG
# 1   Kate (Catherine Keener) and her husband Alex (...              R
# 2   A successful, middle-aged Hollywood songwriter...              R
# 3   Following the closing arguments in a murder tr...             NR
# 4   In 1866, Professor Pierre M. Aronnax (Paul Luk...              G
# 5   Mammoth hunter D'Leh (Steven Strait) has long ...          PG-13
# 6   While on vacation in London, Canadian Richard ...             NR
# 7   Dan Evans (Van Heflin), a drought-plagued Ariz...             NR
# 8   Cultural differences, past loves and personal ...             PG
# 9   Yoshihiro Tatsumi works as a comic-book artist...             NR
# 10  The 16th U.S. president (Walter Huston) is por...             NR
# 11  In this moody Japanese horror film, newly-sing...          PG-13
# 12  Out drinking one night after a fight with her ...              R
# 13  Fico Fellove (Andy Garcia), an apolitical Hava...              R
# 14  A charter-boat captain winds up in the middle ...             NR
# 15  A courtroom rivalry finds its way into the hou...             NR
# 16  During the Spanish Inquisition, Franciscan mon...             PG
# 17  After being frightened by a peeping Tom at her...             PG
# 18  Needing a new partner capable of intricate con...              R
# 19  In this claymation film, celebrated author Mar...              G
# 20  This nature documentary shows the lives of dif...              G
# 21  When King Richard the Lionheart is captured, h...             PG
# 22  Renowned big-game hunter Captain Thorndike (Wa...             NR
# 23  When a family en route to a Christmas Eve gath...              R
# 24  Encouraged by her neighbor (Daryl Hannah), a f...              R
# 25  After the fall of the Roman Empire, English or...          PG-13
# 26  Along with one (Edouard Nikitine) of her live-...             NR
# 27  Mafia flunky Joey Gazelle (Paul Walker) is ord...              R
# 28  Nick (Christopher Jacot) is a successful young...              R
# 29  In the late 21st-century, a vampiric disease m...          PG-13
# 30  In 1965, Klansmen murder a civil-rights worker...              R
# 31  Ten-year-old Arthur must find a way to keep th...             PG
# 32  Bank robbers (Brandon Johnson, Heather Magee) ...              R
# 33  A detective's (Conrad Pla) search for his miss...              R
# 34  Based on the Ernest Hemingway novel, this Worl...             NR
# 35  Tense story of a tough cop attempting to trans...             NR
# 36  Salesman Danny Wright (Greg Kinnear) is workin...              R
# 37  While visiting China, an American high-school ...          PG-13
# 38  After receiving a heart transplant, an enigmat...              G
# 39  The year 1954 finds teen outcast Ralph Walker ...          PG-13
# 40  Elliot Sherman (Michael Showalter) has had ter...          PG-13
# 41  An orphan (Barney Clark) in 19th-century Londo...          PG-13
# 42  In 1836, the Mexican army, led by General Sant...             NR
# 43  Summer G (Richard T. Jones), an aspiring rappe...              R
# 44  The son of Philip of Macedonia (Fredric March)...              G
# 45  Set in postwar London, "Alfie" features Michae...             PG
# 46  Dr. Zach Riley (Aaron Eckhart) begins practici...          PG-13
# 47  Two pastors, one from a wealthy parish in a pr...          PG-13
# 48  Claire, a Dutch girl, discovers a wounded boy ...              R
# 49  After floating in space for 57 years, Lt. Ripl...              R
#
#                                                genres  \
# 0   Action & Adventure, Comedy, Drama, Science Fic...
# 1                                              Comedy
# 2                                     Comedy, Romance
# 3                                     Classics, Drama
# 4            Action & Adventure, Drama, Kids & Family
# 5                 Action & Adventure, Classics, Drama
# 6    Action & Adventure, Classics, Mystery & Suspense
# 7                            Classics, Drama, Western
# 8                              Comedy, Drama, Romance
# 9                                    Animation, Drama
# 10                                    Classics, Drama
# 11  Art House & International, Horror, Mystery & S...
# 12                          Drama, Mystery & Suspense
# 13                                              Drama
# 14                                              Drama
# 15                          Classics, Comedy, Romance
# 16  Art House & International, Drama, Faith & Spir...
# 17                          Drama, Mystery & Suspense
# 18                          Drama, Mystery & Suspense
# 19       Action & Adventure, Animation, Kids & Family
# 20                      Documentary, Special Interest
# 21              Action & Adventure, Classics, Romance
# 22                Classics, Drama, Mystery & Suspense
# 23                 Comedy, Horror, Mystery & Suspense
# 24                   Art House & International, Drama
# 25          Drama, Science Fiction & Fantasy, Romance
# 26                   Art House & International, Drama
# 27      Action & Adventure, Drama, Mystery & Suspense
# 28                                             Comedy
# 29  Action & Adventure, Drama, Horror, Science Fic...
# 30  Action & Adventure, Documentary, Drama, Specia...
# 31  Animation, Kids & Family, Science Fiction & Fa...
# 32                                             Horror
# 33                         Horror, Mystery & Suspense
# 34                           Classics, Drama, Romance
# 35                Classics, Drama, Mystery & Suspense
# 36  Action & Adventure, Comedy, Drama, Mystery & S...
# 37           Art House & International, Comedy, Drama
# 38                   Art House & International, Drama
# 39                                      Comedy, Drama
# 40                                    Comedy, Romance
# 41                               Drama, Kids & Family
# 42       Action & Adventure, Classics, Drama, Western
# 43                                     Drama, Romance
# 44                                           Classics
# 45                   Classics, Comedy, Drama, Romance
# 46                          Drama, Mystery & Suspense
# 47                        Drama, Faith & Spirituality
# 48                          Drama, Mystery & Suspense
# 49  Action & Adventure, Horror, Science Fiction & ...
#
#                                             directors  \
# 0                                      Chris Columbus
# 1                                   Nicole Holofcener
# 2                                       Blake Edwards
# 3                                        Sidney Lumet
# 4                                   Richard Fleischer
# 5                                     Roland Emmerich
# 6                                    Alfred Hitchcock
# 7                                        Delmer Daves
# 8                                Adam Thomas Anderegg
# 9                                           Eric Khoo
# 10                                      D.W. Griffith
# 11                                       Hideo Nakata
# 12                                    Jonathan Kaplan
# 13                                        Andy Garcia
# 14                                     Michael Curtiz
# 15                                       George Cukor
# 16                                     Mary McGuckian
# 17                                       Joseph Losey
# 18       Greggory Jacobs, Gregory Jacobs, Greg Jacobs
# 19                                        Will Vinton
# 20                    Andy Byatt, Alastair Fothergill
# 21                   Michael Curtiz, William Keighley
# 22                                         Fritz Lang
# 23  Jean-Baptiste Andrea, Fabrice Canepa, Jean-Bap...
# 24                                        María Lidón
# 25                                     Kevin Reynolds
# 26                                 Sébastien Lifshitz
# 27                                       Wayne Kramer
# 28                                     Mark Griffiths
# 29                                        Kurt Wimmer
# 30                                    Paola di Florio
# 31                                         Luc Besson
# 32                                        Stevan Mena
# 33               Wilhelm Liebenberg, Federico Sanchez
# 34            Charles Vidor, John Hudson, John Huston
# 35                                  Richard Fleischer
# 36                          Bob Yari, Richard Shepard
# 37                        Jeff Kramer, Jeffrey Kramer
# 38                                       Claire Denis
# 39                                    Michael McGowan
# 40                                  Michael Showalter
# 41                                     Roman Polanski
# 42                                         John Wayne
# 43                           Christopher Scott Cherot
# 44                                      Robert Rossen
# 45                                      Lewis Gilbert
# 46                               Joshua Michael Stern
# 47                                       Steve Taylor
# 48                                 Paula Van der Oest
# 49                                      James Cameron
#
#                                               authors  \
# 0          Craig Titley, Chris Columbus, Rick Riordan
# 1                                   Nicole Holofcener
# 2                                       Blake Edwards
# 3                                       Reginald Rose
# 4                                         Earl Felton
# 5                      Harald Kloser, Roland Emmerich
# 6   Alma Reville, Charles Bennett, Ian Hay, Alfred...
# 7                                      Halsted Welles
# 8                Jack Weyland, Janine Whetton Gilbert
# 9                        Eric Khoo, Yoshihiro Tatsumi
# 10             Gerrit J. Lloyd, Stephen Vincent Benét
# 11  Hideo Hakata, Takashige Ichise, Yoshihiro Naka...
# 12                                          Tom Topor
# 13      G. Cabrera Infante, Guillermo Cabrera Infante
# 14                                  Ranald MacDougall
# 15                          Garson Kanin, Ruth Gordon
# 16                                     Mary McGuckian
# 17         Robert Thoeren, Hugo Butler, Dalton Trumbo
# 18  Gregory Jacobs, Fabián Bielinsky, Steven Soder...
# 19                                    Susan Shadburne
# 20         Alastair Fothergill, Andy Byatt, Tim Ecott
# 21  Norman Reilly Raine, Seton I. Miller, Michael ...
# 22                                     Dudley Nichols
# 23               Jean-Baptiste Andrea, Fabrice Canepa
# 24                        Adela Ibañez, Isabel Pisano
# 25                                     Dean Georgaris
# 26               Sébastien Lifshitz, Stéphane Bouquet
# 27                                       Wayne Kramer
# 28                        Eric Goodman, Kelly Senecal
# 29                                        Kurt Wimmer
# 30                                    Paola di Florio
# 31                          Luc Besson, Celine Garcia
# 32                                        Stevan Mena
# 33               Wilhelm Liebenberg, Federico Sanchez
# 34                                          Ben Hecht
# 35                      Earl Felton, Martin Goldsmith
# 36                  Richard Shepard, Richard Shepherd
# 37                        Jeff Kramer, Jeffrey Kramer
# 38                     Claire Denis, Jean-Pol Fargeau
# 39                                    Michael McGowan
# 40                                  Michael Showalter
# 41                                     Ronald Harwood
# 42                                 James Edward Grant
# 43  Charles E. Drew, Christopher Scott Cherot, Cha...
# 44                                      Robert Rossen
# 45                                      Bill Naughton
# 46                               Joshua Michael Stern
# 47  Steve Taylor, Chip Arnold, Ben Pearson, Henry ...
# 48                                        Carel Donck
# 49                                      James Cameron
#
#                                                actors  runtime  \
# 0   Logan Lerman, Brandon T. Jackson, Alexandra Da...      119
# 1   Catherine Keener, Amanda Peet, Oliver Platt, R...       90
# 2   Dudley Moore, Bo Derek, Julie Andrews, Robert ...      122
# 3   Martin Balsam, John Fiedler, Lee J. Cobb, E.G....       95
# 4   James Mason, Kirk Douglas, Paul Lukas, Peter L...      127
# 5   Steven Strait, Camilla Belle, Cliff Curtis, Jo...      109
# 6   Robert Donat, Madeleine Carroll, Godfrey Tearl...       80
# 7   Glenn Ford, Van Heflin, Felicia Farr, Leora Da...       92
# 8   Heather Beers, Gary Neilson, Lisa McCammon, Ja...      103
# 9   Tetsuya Bessho, Motoko Gollent, Yoshihiro Tats...       96
# 10  Walter Huston, Una Merkel, Kay Hammond, Ian Ke...       97
# 11  Hitomi Kuroki, Rio Kanno, Shigemitsu Ogi, Mire...      100
# 12  Jodie Foster, Kelly McGillis, Bernie Coulson, ...      110
# 13  Andy Garcia, Dustin Hoffman, Bill Murray, Inés...      143
# 14  John Garfield, Patricia Neal, Phyllis Thaxter,...       97
# 15  Spencer Tracy, Katharine Hepburn, Judy Hollida...      101
# 16  Gabriel Byrne, F. Murray Abraham, Kathy Bates,...      124
# 17  Van Heflin, Evelyn Keyes, Katherine Warren, Jo...       92
# 18  John C. Reilly, Diego Luna, Maggie Gyllenhaal,...       87
# 19  James Whitmore, Michele Mariana, Gary Krug, Ch...       86
# 20                     Pierce Brosnan, Michael Gambon       90
# 21  Errol Flynn, Olivia de Havilland, Basil Rathbo...      102
# 22  Walter Pidgeon, Joan Bennett, George Sanders, ...      100
# 23  Ray Wise, Lin Shaye, Mick Cain, Alexandra Hold...       83
# 24  Daryl Hannah, Denise Richards, Joaquim de Alme...       77
# 25  James Franco, Sophia Myles, Rufus Sewell, Davi...      126
# 26  Stéphanie Michelini, Josiane Stoleru, Yasmine ...       94
# 27  Paul Walker, Cameron Bright, Vera Farmiga, Kar...      121
# 28  Christopher Jacot, Shawn Roberts, Ryan Bellevi...       93
# 29  Milla Jovovich, Cameron Bright, Nick Chinlund,...       88
# 30  Mary Liuzzo, Tony Liuzzo, Sally Liuzzo, Penny ...       75
# 31  Freddie Highmore, Mia Farrow, Penny Balfour, D...       94
# 32  Samantha Dark, R. Brandon Johnson, Heather Mag...       90
# 33  Sarah Manninen, Caroline Neron, Victoria Sanch...      108
# 34  Rock Hudson, Jennifer Jones, Vittorio De Sica,...      150
# 35  Charlie MacGraw, Charles McGraw, Marie Windsor...       71
# 36  Pierce Brosnan, Greg Kinnear, Hope Davis, Phil...       97
# 37  Mika Boorem, Wang Luoyong, Yi Ding (II), Beau ...      107
# 38  Beatrice Dalle, Michael Subor, Jean-Marc Terii...      130
# 39  Adam Butcher, Campbell Scott, Gordon Pinsent, ...       98
# 40  Michael Showalter, Elizabeth Banks, Michelle W...       91
# 41  Ben Kingsley, Barney Clark, Leanne Rowe, Mark ...      130
# 42  John Wayne, Richard Widmark, Laurence Harvey, ...      192
# 43  Richard T. Jones, Blair Underwood, Chenoa Maxw...       96
# 44  Richard Burton, Fredric March, Claire Bloom, D...      141
# 45  Michael Caine, Millicent Martin, Julia Foster,...      114
# 46  Aaron Eckhart, Ian McKellen, Brittany Murphy, ...      102
# 47  Michael W. Smith, Jeff Obafemi Carr, Jonathan ...      104
# 48  Laurien Van Den Broeck, Hunter Bussemaker, Joh...       90
# 49  Sigourney Weaver, Carrie Henn, Michael Biehn, ...      137
#
#               production_company  ...  streaming_release_year  \
# 0               20th Century Fox  ...                    2015
# 1         Sony Pictures Classics  ...                    2012
# 2                    Waner Bros.  ...                    2014
# 3           Criterion Collection  ...                    2017
# 4                         Disney  ...                    2016
# 5          Warner Bros. Pictures  ...                    2013
# 6   Gaumont British Distributors  ...                    2017
# 7              Columbia Pictures  ...                    2012
# 8            Excel Entertainment  ...                    2017
# 9                New Video Group  ...                    2016
# 10                United Artists  ...                    2013
# 11              Toho Company Ltd  ...                    2017
# 12            Paramount Pictures  ...                    2016
# 13             Magnolia Pictures  ...                    2017
# 14             Warner Home Video  ...                    2016
# 15        MGM Home Entertainment  ...                    2008
# 16            Fine Line Features  ...                    2014
# 17             VCI Entertainment  ...                    2016
# 18         Warner Bros. Pictures  ...                    2016
# 19      Eureka Entertainment Ltd  ...                    2017
# 20                 Miramax Flims  ...                    2016
# 21                  Warner Bros.  ...                    2014
# 22         Twentieth Century Fox  ...                    2014
# 23       LionsGate Entertainment  ...                    2018
# 24          Dolores Pictures LLC  ...                    2014
# 25              20th Century Fox  ...                    2015
# 26                    Wellspring  ...                    2005
# 27               New Line Cinema  ...                    2008
# 28              Séville Pictures  ...                    2017
# 29                 Sony Pictures  ...                    2012
# 30             Emerging Pictures  ...                    2016
# 31                           MGM  ...                    2016
# 32      Anchor Bay Entertainment  ...                    2017
# 33              Regent Releasing  ...                    2016
# 34                           Fox  ...                    2012
# 35             Warner Home Video  ...                    2012
# 36         The Weinstein Company  ...                    2016
# 37         Dark Forest Releasing  ...                    2016
# 38                    Wellspring  ...                    2006
# 39                           IDP  ...                    2017
# 40                     IFC Films  ...                    2018
# 41                 Sony Pictures  ...                    2012
# 42            Batjac Productions  ...                    2016
# 43              Slow Hand Cinema  ...                    2018
# 44                United Artists  ...                    2017
# 45            Paramount Pictures  ...                    2013
# 46                  Senator Film  ...                    2016
# 47                 Sony Pictures  ...                    2006
# 48              Indican Pictures  ...                    2020
# 49              20th Century Fox  ...                    2015
#
#     tomatometer_status  tomatometer_rating  tomatometer_count audience_status  \
# 0               Rotten                  49                149         Spilled
# 1                Fresh                  87                142         Upright
# 2                Fresh                  67                 24         Spilled
# 3                Fresh                 100                 54         Upright
# 4                Fresh                  89                 27         Upright
# 5               Rotten                   8                149         Spilled
# 6                Fresh                  96                 51         Upright
# 7                Fresh                  96                 28         Upright
# 8               Rotten                  20                 10         Upright
# 9                Fresh                  94                 18         Upright
# 10               Fresh                  82                 11         Spilled
# 11               Fresh                  80                 15         Upright
# 12               Fresh                  91                 22         Upright
# 13              Rotten                  25                 83         Upright
# 14               Fresh                 100                 10         Upright
# 15               Fresh                  96                 28         Upright
# 16              Rotten                   4                 24         Spilled
# 17               Fresh                 100                 18         Upright
# 18               Fresh                  69                124         Spilled
# 19               Fresh                  80                  5         Upright
# 20               Fresh                  67                 52         Upright
# 21               Fresh                 100                 48         Upright
# 22               Fresh                  92                 12         Upright
# 23               Fresh                  75                  8         Upright
# 24              Rotten                   0                  6         Upright
# 25              Rotten                  31                121         Upright
# 26               Fresh                  63                 16         Upright
# 27              Rotten                  41                131         Upright
# 28              Rotten                   0                  5         Upright
# 29              Rotten                   8                 83         Spilled
# 30               Fresh                  93                 15         Spilled
# 31              Rotten                  22                 92         Spilled
# 32              Rotten                  33                 18         Upright
# 33              Rotten                  21                 34         Spilled
# 34              Rotten                   0                 12         Spilled
# 35               Fresh                 100                 11         Upright
# 36               Fresh                  75                156         Upright
# 37              Rotten                  15                 13         Upright
# 38               Fresh                  87                 30         Upright
# 39               Fresh                  64                 69         Upright
# 40              Rotten                  32                 75         Upright
# 41               Fresh                  61                143         Upright
# 42              Rotten                  52                 21         Upright
# 43              Rotten                  24                 29         Upright
# 44              Rotten                   0                  8         Spilled
# 45               Fresh                  96                 27         Upright
# 46              Rotten                  14                  7         Upright
# 47              Rotten                  44                 16         Upright
# 48               Fresh                  60                 10         Upright
# 49               Fresh                  97                 76         Upright
#
#     audience_rating  audience_count tomatometer_top_critics_count  \
# 0                53          254421                            43
# 1                64           11574                            44
# 2                53           14684                             2
# 3                97          105386                             6
# 4                74           68918                             5
# 5                37          411140                            37
# 6                86           23890                             8
# 7                79            9243                             6
# 8                87            4819                             0
# 9                80             486                             7
# 10               40             457                             4
# 11               66           21475                             3
# 12               79           20821                             1
# 13               64           25944                            37
# 14               86             335                             1
# 15               86           10563                             6
# 16               35            1935                            13
# 17               86             286                             6
# 18               57            6711                            35
# 19               82            1046                             1
# 20               80            4692                            18
# 21               89           33946                             8
# 22               75             554                             0
# 23               60           10373                             1
# 24               63             914                             4
# 25               71          220956                            36
# 26               80             867                             4
# 27               79          135400                            39
# 28               61           13033                             2
# 29               30          279994                            21
# 30               48             866                             7
# 31               56          134483                            30
# 32               83            2622                             4
# 33               39            1295                            10
# 34               37            1460                             6
# 35               88            1135                             0
# 36               65           73701                            39
# 37               66            2059                             6
# 38               73            9701                            10
# 39               85            6203                            26
# 40               75            7436                            25
# 41               63           23294                            39
# 42               63            7337                             4
# 43               60            1143                            17
# 44               42            5383                             1
# 45               76           14669                             6
# 46               65            4059                             1
# 47               78           79542                             8
# 48               67            1430                             6
# 49               94          429674                            17
#
#     tomatometer_fresh_critics_count  tomatometer_rotten_critics_count
# 0                                73                                76
# 1                               123                                19
# 2                                16                                 8
# 3                                54                                 0
# 4                                24                                 3
# 5                                12                               137
# 6                                49                                 2
# 7                                27                                 1
# 8                                 2                                 8
# 9                                17                                 1
# 10                                9                                 2
# 11                               12                                 3
# 12                               20                                 2
# 13                               21                                62
# 14                               10                                 0
# 15                               27                                 1
# 16                                1                                23
# 17                               18                                 0
# 18                               85                                39
# 19                                4                                 1
# 20                               35                                17
# 21                               48                                 0
# 22                               11                                 1
# 23                                6                                 2
# 24                                0                                 6
# 25                               38                                83
# 26                               10                                 6
# 27                               54                                77
# 28                                0                                 5
# 29                                7                                76
# 30                               14                                 1
# 31                               20                                72
# 32                                6                                12
# 33                                7                                27
# 34                                0                                12
# 35                               11                                 0
# 36                              117                                39
# 37                                2                                11
# 38                               26                                 4
# 39                               44                                25
# 40                               24                                51
# 41                               87                                56
# 42                               11                                10
# 43                                7                                22
# 44                                0                                 8
# 45                               26                                 1
# 46                                1                                 6
# 47                                7                                 9
# 48                                6                                 4
# 49                               74                                 2
#
# [50 rows x 23 columns]

# %%
moviedf.columns.tolist()
# Out:
# ['rotten_tomatoes_link',
#  'movie_title',
#  'movie_info',
#  'content_rating',
#  'genres',
#  'directors',
#  'authors',
#  'actors',
#  'runtime',
#  'production_company',
#  'release_month',
#  'streaming_month',
#  'release_year',
#  'streaming_release_year',
#  'tomatometer_status',
#  'tomatometer_rating',
#  'tomatometer_count',
#  'audience_status',
#  'audience_rating',
#  'audience_count',
#  'tomatometer_top_critics_count',
#  'tomatometer_fresh_critics_count',
#  'tomatometer_rotten_critics_count']

# %%
movie_by_month_df=moviedf.groupby('release_month')
movie_by_month_df.head()
# Out:
#                       rotten_tomatoes_link  \
# 0                                m/0814255
# 1                                m/0878835
# 2                                     m/10
# 3                   m/1000013-12_angry_men
# 4    m/1000079-20000_leagues_under_the_sea
# 5                               m/10000_bc
# 6                       m/1000121-39_steps
# 7                    m/1000123-310_to_yuma
# 8                        m/10002008-charly
# 9                           m/tatsumi_2011
# 10               m/1000204-abraham_lincoln
# 11                   m/10002114-dark_water
# 12                       m/1000224-accused
# 13                    m/10002516-lost_city
# 14               m/10002519-breaking_point
# 15                     m/1000253-adams_rib
# 16       m/10002635-bridge_of_san_luis_rey
# 17                      m/10002673-prowler
# 18                     m/10003276-criminal
# 19      m/1000334-adventures_of_mark_twain
# 20                    m/10003437-deep_blue
# 21      m/1000355-adventures_of_robin_hood
# 22                     m/10003876-man_hunt
# 23                     m/10003925-dead_end
# 24                        m/10004069-whore
# 25           m/10004209-tristan_and_isolde
# 26                    m/10004226-wild_side
# 27               m/10004288-running_scared
# 28           m/10004352-going_the_distance
# 29                  m/10004504-ultraviolet
# 30            m/10004635-home_of_the_brave
# 31                       m/10004659-arthur
# 32                  m/10004684-malevolence
# 33                      m/10004697-eternal
# 34             m/10004835-farewell_to_arms
# 35                m/10004890-narrow_margin
# 37                        m/10005057-smile
# 38                     m/10005104-intruder
# 39                  m/10005178-saint_ralph
# 42                         m/1000560-alamo
# 44           m/1000580-alexander_the_great
# 47            m/10006007-the_second_chance
# 48                    m/10006057-moonlight
# 49                        m/1000617-aliens
# 50                         m/10006188-rise
# 53                              m/10006324
# 54                        m/10006343-dirty
# 55                   m/10006370-stay_alive
# 57                    m/10006434-dreamland
# 58             m/1000654-all_the_kings_men
# 63           m/10006849-once_in_a_lifetime
# 66              m/10007333-bon_cop_bad_cop
# 67                m/10007415-amazing_grace
# 73         m/10007893-its_a_boy_girl_thing
# 76                    m/10007916_interview
# 81                      m/10008005-moliere
# 82                   m/10008140-borderland
# 84                    m/10008234-alexandra
# 87              m/10008502-christmas_carol
# 126                m/10009001-the_freshman
#
#                                            movie_title  \
# 0    Percy Jackson & the Olympians: The Lightning T...
# 1                                          Please Give
# 2                                                   10
# 3                      12 Angry Men (Twelve Angry Men)
# 4                         20,000 Leagues Under The Sea
# 5                                          10,000 B.C.
# 6                                         The 39 Steps
# 7                                         3:10 to Yuma
# 8                            Charly (A Heartbeat Away)
# 9                                              Tatsumi
# 10                                     Abraham Lincoln
# 11                                          Dark Water
# 12                                         The Accused
# 13                                       The Lost City
# 14                                  The Breaking Point
# 15                                          Adam's Rib
# 16                          The Bridge of San Luis Rey
# 17                       The Prowler (Cost of Living )
# 18                                            Criminal
# 19                        The Adventures of Mark Twain
# 20                                           Deep Blue
# 21                        The Adventures of Robin Hood
# 22                                            Man Hunt
# 23                                            Dead End
# 24                                               Whore
# 25                                    Tristan & Isolde
# 26                                           Wild Side
# 27                                      Running Scared
# 28                                  Going the Distance
# 29                                         Ultraviolet
# 30                                   Home of the Brave
# 31   Arthur and the Invisibles (Arthur and the Mini...
# 32                                         Malevolence
# 33                                             Eternal
# 34                                  A Farewell To Arms
# 35                                   The Narrow Margin
# 37                                               Smile
# 38                             The Intruder (L'Intrus)
# 39                                         Saint Ralph
# 42                                           The Alamo
# 44                                 Alexander the Great
# 47                                   The Second Chance
# 48                                           Moonlight
# 49                                              Aliens
# 50                                  Rise: Blood Hunter
# 53    The Mostly Unfabulous Social Life of Ethan Green
# 54                                               Dirty
# 55                                          Stay Alive
# 57                                           Dreamland
# 58                                  All the King's Men
# 63   Once in a Lifetime: The Extraordinary Story of...
# 66                                    Bon Cop, Bad Cop
# 67                                       Amazing Grace
# 73                               It's a Boy Girl Thing
# 76                                           Interview
# 81                                             Molière
# 82                                          Borderland
# 84                                           Alexandra
# 87                          Disney's A Christmas Carol
# 126                                       The Freshman
#
#                                             movie_info content_rating  \
# 0    Always trouble-prone, the life of teenager Per...             PG
# 1    Kate (Catherine Keener) and her husband Alex (...              R
# 2    A successful, middle-aged Hollywood songwriter...              R
# 3    Following the closing arguments in a murder tr...             NR
# 4    In 1866, Professor Pierre M. Aronnax (Paul Luk...              G
# 5    Mammoth hunter D'Leh (Steven Strait) has long ...          PG-13
# 6    While on vacation in London, Canadian Richard ...             NR
# 7    Dan Evans (Van Heflin), a drought-plagued Ariz...             NR
# 8    Cultural differences, past loves and personal ...             PG
# 9    Yoshihiro Tatsumi works as a comic-book artist...             NR
# 10   The 16th U.S. president (Walter Huston) is por...             NR
# 11   In this moody Japanese horror film, newly-sing...          PG-13
# 12   Out drinking one night after a fight with her ...              R
# 13   Fico Fellove (Andy Garcia), an apolitical Hava...              R
# 14   A charter-boat captain winds up in the middle ...             NR
# 15   A courtroom rivalry finds its way into the hou...             NR
# 16   During the Spanish Inquisition, Franciscan mon...             PG
# 17   After being frightened by a peeping Tom at her...             PG
# 18   Needing a new partner capable of intricate con...              R
# 19   In this claymation film, celebrated author Mar...              G
# 20   This nature documentary shows the lives of dif...              G
# 21   When King Richard the Lionheart is captured, h...             PG
# 22   Renowned big-game hunter Captain Thorndike (Wa...             NR
# 23   When a family en route to a Christmas Eve gath...              R
# 24   Encouraged by her neighbor (Daryl Hannah), a f...              R
# 25   After the fall of the Roman Empire, English or...          PG-13
# 26   Along with one (Edouard Nikitine) of her live-...             NR
# 27   Mafia flunky Joey Gazelle (Paul Walker) is ord...              R
# 28   Nick (Christopher Jacot) is a successful young...              R
# 29   In the late 21st-century, a vampiric disease m...          PG-13
# 30   In 1965, Klansmen murder a civil-rights worker...              R
# 31   Ten-year-old Arthur must find a way to keep th...             PG
# 32   Bank robbers (Brandon Johnson, Heather Magee) ...              R
# 33   A detective's (Conrad Pla) search for his miss...              R
# 34   Based on the Ernest Hemingway novel, this Worl...             NR
# 35   Tense story of a tough cop attempting to trans...             NR
# 37   While visiting China, an American high-school ...          PG-13
# 38   After receiving a heart transplant, an enigmat...              G
# 39   The year 1954 finds teen outcast Ralph Walker ...          PG-13
# 42   In 1836, the Mexican army, led by General Sant...             NR
# 44   The son of Philip of Macedonia (Fredric March)...              G
# 47   Two pastors, one from a wealthy parish in a pr...          PG-13
# 48   Claire, a Dutch girl, discovers a wounded boy ...              R
# 49   After floating in space for 57 years, Lt. Ripl...              R
# 50   Sadie (Lucy Liu), a reporter, investigates an ...              R
# 53   A young man named Ethan (Daniel Letterle) is h...              R
# 54   Armando Sancho (Clifton Collins Jr.) is a form...              R
# 55   Teenagers decide to pass idle time by playing ...          PG-13
# 57   Teenage Aubrey (Agnes Bruckner) is always ther...          PG-13
# 58   Drama about the rise and fall of a corrupt sou...             PG
# 63   This documentary looks back on a time when soc...          PG-13
# 66   Two policemen (Colm Feore, Patrick Huard) from...              R
# 67   In 18th-century England, House of Commons memb...             PG
# 73   Pretty teen girl Nell (Samaire Armstrong) is e...          PG-13
# 76   Pierre Peders (Steve Buscemi), a political rep...              R
# 81   In 17th-century France, playwright and actor M...          PG-13
# 82   Ed (Brian Presley), Henry (Jake Muxworthy) and...              R
# 84   Elderly Aleksandra (Galina Vishnevskaya) visit...             NR
# 87   Though London awaits the joyful arrival of Chr...             PG
# 126  Clark Kellogg (Matthew Broderick) is robbed mo...             PG
#
#                                                 genres  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...
# 1                                               Comedy
# 2                                      Comedy, Romance
# 3                                      Classics, Drama
# 4             Action & Adventure, Drama, Kids & Family
# 5                  Action & Adventure, Classics, Drama
# 6     Action & Adventure, Classics, Mystery & Suspense
# 7                             Classics, Drama, Western
# 8                               Comedy, Drama, Romance
# 9                                     Animation, Drama
# 10                                     Classics, Drama
# 11   Art House & International, Horror, Mystery & S...
# 12                           Drama, Mystery & Suspense
# 13                                               Drama
# 14                                               Drama
# 15                           Classics, Comedy, Romance
# 16   Art House & International, Drama, Faith & Spir...
# 17                           Drama, Mystery & Suspense
# 18                           Drama, Mystery & Suspense
# 19        Action & Adventure, Animation, Kids & Family
# 20                       Documentary, Special Interest
# 21               Action & Adventure, Classics, Romance
# 22                 Classics, Drama, Mystery & Suspense
# 23                  Comedy, Horror, Mystery & Suspense
# 24                    Art House & International, Drama
# 25           Drama, Science Fiction & Fantasy, Romance
# 26                    Art House & International, Drama
# 27       Action & Adventure, Drama, Mystery & Suspense
# 28                                              Comedy
# 29   Action & Adventure, Drama, Horror, Science Fic...
# 30   Action & Adventure, Documentary, Drama, Specia...
# 31   Animation, Kids & Family, Science Fiction & Fa...
# 32                                              Horror
# 33                          Horror, Mystery & Suspense
# 34                            Classics, Drama, Romance
# 35                 Classics, Drama, Mystery & Suspense
# 37            Art House & International, Comedy, Drama
# 38                    Art House & International, Drama
# 39                                       Comedy, Drama
# 42        Action & Adventure, Classics, Drama, Western
# 44                                            Classics
# 47                         Drama, Faith & Spirituality
# 48                           Drama, Mystery & Suspense
# 49   Action & Adventure, Horror, Science Fiction & ...
# 50                          Horror, Mystery & Suspense
# 53                                       Comedy, Drama
# 54                                               Drama
# 55                          Horror, Mystery & Suspense
# 57                    Art House & International, Drama
# 58                                     Classics, Drama
# 63                       Documentary, Sports & Fitness
# 66                          Action & Adventure, Comedy
# 67                           Drama, Mystery & Suspense
# 73                                     Comedy, Romance
# 76                    Art House & International, Drama
# 81                                              Comedy
# 82                   Drama, Horror, Mystery & Suspense
# 84                                               Drama
# 87   Animation, Drama, Kids & Family, Science Ficti...
# 126                                      Comedy, Drama
#
#                                              directors  \
# 0                                       Chris Columbus
# 1                                    Nicole Holofcener
# 2                                        Blake Edwards
# 3                                         Sidney Lumet
# 4                                    Richard Fleischer
# 5                                      Roland Emmerich
# 6                                     Alfred Hitchcock
# 7                                         Delmer Daves
# 8                                 Adam Thomas Anderegg
# 9                                            Eric Khoo
# 10                                       D.W. Griffith
# 11                                        Hideo Nakata
# 12                                     Jonathan Kaplan
# 13                                         Andy Garcia
# 14                                      Michael Curtiz
# 15                                        George Cukor
# 16                                      Mary McGuckian
# 17                                        Joseph Losey
# 18        Greggory Jacobs, Gregory Jacobs, Greg Jacobs
# 19                                         Will Vinton
# 20                     Andy Byatt, Alastair Fothergill
# 21                    Michael Curtiz, William Keighley
# 22                                          Fritz Lang
# 23   Jean-Baptiste Andrea, Fabrice Canepa, Jean-Bap...
# 24                                         María Lidón
# 25                                      Kevin Reynolds
# 26                                  Sébastien Lifshitz
# 27                                        Wayne Kramer
# 28                                      Mark Griffiths
# 29                                         Kurt Wimmer
# 30                                     Paola di Florio
# 31                                          Luc Besson
# 32                                         Stevan Mena
# 33                Wilhelm Liebenberg, Federico Sanchez
# 34             Charles Vidor, John Hudson, John Huston
# 35                                   Richard Fleischer
# 37                         Jeff Kramer, Jeffrey Kramer
# 38                                        Claire Denis
# 39                                     Michael McGowan
# 42                                          John Wayne
# 44                                       Robert Rossen
# 47                                        Steve Taylor
# 48                                  Paula Van der Oest
# 49                                       James Cameron
# 50                                 Sebastian Gutierrez
# 53                                       George Bamber
# 54                                        Chris Fisher
# 55                                  William Brent Bell
# 57                                       Jason Matzner
# 58                                       Robert Rossen
# 63                            Paul Crowder, John Dower
# 66                                         Eric Canuel
# 67                                       Michael Apted
# 73                                         Nick Hurran
# 76                                       Steve Buscemi
# 81                       Laurent Tirard, Laurent Sivot
# 82                                          Zev Berman
# 84                                   Aleksandr Sokurov
# 87                                     Robert Zemeckis
# 126                                     Andrew Bergman
#
#                                                authors  \
# 0           Craig Titley, Chris Columbus, Rick Riordan
# 1                                    Nicole Holofcener
# 2                                        Blake Edwards
# 3                                        Reginald Rose
# 4                                          Earl Felton
# 5                       Harald Kloser, Roland Emmerich
# 6    Alma Reville, Charles Bennett, Ian Hay, Alfred...
# 7                                       Halsted Welles
# 8                 Jack Weyland, Janine Whetton Gilbert
# 9                         Eric Khoo, Yoshihiro Tatsumi
# 10              Gerrit J. Lloyd, Stephen Vincent Benét
# 11   Hideo Hakata, Takashige Ichise, Yoshihiro Naka...
# 12                                           Tom Topor
# 13       G. Cabrera Infante, Guillermo Cabrera Infante
# 14                                   Ranald MacDougall
# 15                           Garson Kanin, Ruth Gordon
# 16                                      Mary McGuckian
# 17          Robert Thoeren, Hugo Butler, Dalton Trumbo
# 18   Gregory Jacobs, Fabián Bielinsky, Steven Soder...
# 19                                     Susan Shadburne
# 20          Alastair Fothergill, Andy Byatt, Tim Ecott
# 21   Norman Reilly Raine, Seton I. Miller, Michael ...
# 22                                      Dudley Nichols
# 23                Jean-Baptiste Andrea, Fabrice Canepa
# 24                         Adela Ibañez, Isabel Pisano
# 25                                      Dean Georgaris
# 26                Sébastien Lifshitz, Stéphane Bouquet
# 27                                        Wayne Kramer
# 28                         Eric Goodman, Kelly Senecal
# 29                                         Kurt Wimmer
# 30                                     Paola di Florio
# 31                           Luc Besson, Celine Garcia
# 32                                         Stevan Mena
# 33                Wilhelm Liebenberg, Federico Sanchez
# 34                                           Ben Hecht
# 35                       Earl Felton, Martin Goldsmith
# 37                         Jeff Kramer, Jeffrey Kramer
# 38                      Claire Denis, Jean-Pol Fargeau
# 39                                     Michael McGowan
# 42                                  James Edward Grant
# 44                                       Robert Rossen
# 47   Steve Taylor, Chip Arnold, Ben Pearson, Henry ...
# 48                                         Carel Donck
# 49                                       James Cameron
# 50                                 Sebastian Gutierrez
# 53                                        David Vernon
# 54                Chris Fisher, Gil Reavill, Eric Saks
# 55                William Brent Bell, Matthew Peterman
# 57                          Tom Willett, Jason Matzner
# 58                   Robert Rossen, Robert Penn Warren
# 63                             Mark Monroe, John Dower
# 66   Leila Basen, Alex Epstein, Patrick Huard, Kevi...
# 67                                       Steven Knight
# 73                                         Geoff Deane
# 76                      Steve Buscemi, David Schechter
# 81   Laurent Tirard, Grégoire Vigneron, Fanny Valet...
# 82                             Zev Berman, Eric Poppen
# 84                                   Aleksandr Sokurov
# 87                                     Robert Zemeckis
# 126                                     Andrew Bergman
#
#                                                 actors  runtime  \
# 0    Logan Lerman, Brandon T. Jackson, Alexandra Da...      119
# 1    Catherine Keener, Amanda Peet, Oliver Platt, R...       90
# 2    Dudley Moore, Bo Derek, Julie Andrews, Robert ...      122
# 3    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....       95
# 4    James Mason, Kirk Douglas, Paul Lukas, Peter L...      127
# 5    Steven Strait, Camilla Belle, Cliff Curtis, Jo...      109
# 6    Robert Donat, Madeleine Carroll, Godfrey Tearl...       80
# 7    Glenn Ford, Van Heflin, Felicia Farr, Leora Da...       92
# 8    Heather Beers, Gary Neilson, Lisa McCammon, Ja...      103
# 9    Tetsuya Bessho, Motoko Gollent, Yoshihiro Tats...       96
# 10   Walter Huston, Una Merkel, Kay Hammond, Ian Ke...       97
# 11   Hitomi Kuroki, Rio Kanno, Shigemitsu Ogi, Mire...      100
# 12   Jodie Foster, Kelly McGillis, Bernie Coulson, ...      110
# 13   Andy Garcia, Dustin Hoffman, Bill Murray, Inés...      143
# 14   John Garfield, Patricia Neal, Phyllis Thaxter,...       97
# 15   Spencer Tracy, Katharine Hepburn, Judy Hollida...      101
# 16   Gabriel Byrne, F. Murray Abraham, Kathy Bates,...      124
# 17   Van Heflin, Evelyn Keyes, Katherine Warren, Jo...       92
# 18   John C. Reilly, Diego Luna, Maggie Gyllenhaal,...       87
# 19   James Whitmore, Michele Mariana, Gary Krug, Ch...       86
# 20                      Pierce Brosnan, Michael Gambon       90
# 21   Errol Flynn, Olivia de Havilland, Basil Rathbo...      102
# 22   Walter Pidgeon, Joan Bennett, George Sanders, ...      100
# 23   Ray Wise, Lin Shaye, Mick Cain, Alexandra Hold...       83
# 24   Daryl Hannah, Denise Richards, Joaquim de Alme...       77
# 25   James Franco, Sophia Myles, Rufus Sewell, Davi...      126
# 26   Stéphanie Michelini, Josiane Stoleru, Yasmine ...       94
# 27   Paul Walker, Cameron Bright, Vera Farmiga, Kar...      121
# 28   Christopher Jacot, Shawn Roberts, Ryan Bellevi...       93
# 29   Milla Jovovich, Cameron Bright, Nick Chinlund,...       88
# 30   Mary Liuzzo, Tony Liuzzo, Sally Liuzzo, Penny ...       75
# 31   Freddie Highmore, Mia Farrow, Penny Balfour, D...       94
# 32   Samantha Dark, R. Brandon Johnson, Heather Mag...       90
# 33   Sarah Manninen, Caroline Neron, Victoria Sanch...      108
# 34   Rock Hudson, Jennifer Jones, Vittorio De Sica,...      150
# 35   Charlie MacGraw, Charles McGraw, Marie Windsor...       71
# 37   Mika Boorem, Wang Luoyong, Yi Ding (II), Beau ...      107
# 38   Beatrice Dalle, Michael Subor, Jean-Marc Terii...      130
# 39   Adam Butcher, Campbell Scott, Gordon Pinsent, ...       98
# 42   John Wayne, Richard Widmark, Laurence Harvey, ...      192
# 44   Richard Burton, Fredric March, Claire Bloom, D...      141
# 47   Michael W. Smith, Jeff Obafemi Carr, Jonathan ...      104
# 48   Laurien Van Den Broeck, Hunter Bussemaker, Joh...       90
# 49   Sigourney Weaver, Carrie Henn, Michael Biehn, ...      137
# 50   Lucy Liu, Michael Chiklis, Carla Gugino, James...       97
# 53   Daniel Letterle, Meredith Baxter, David Monaha...       88
# 54   Cuba Gooding Jr., Wyclef Jean, Keith David, Cl...       97
# 55   Jon Foster, Frankie Muniz, Samaire Armstrong, ...       85
# 57   Agnes Bruckner, Kelli Garner, Justin Long, Gin...       88
# 58   Broderick Crawford, Mercedes McCambridge, John...      109
# 63   Johann Cruyff, Franz Beckenbauer, Werner Roth,...       97
# 66   Patrick Huard, Colm Feore, Lucie Laurier, Sara...      116
# 67   Ioan Gruffudd, Romola Garai, Michael Gambon, B...      116
# 73   Samaire Armstrong, Kevin Zegers, Emily Hampshi...       95
# 76   Sienna Miller, Steve Buscemi, Michael Buscemi,...       84
# 81   Romain Duris, Édouard Baer, Fabrice Luchini, L...      120
# 82   Brian Presley, Martha Higareda, Jake Muxworthy...      104
# 84   Galina Vishnevskaya, Vasily Shetvtsov, Vasily ...       95
# 87   Colin Firth, Leslie Zemeckis, Cary Elwes, Robi...       95
# 126  Marlon Brando, Matthew Broderick, Bruno Kirby,...      102
#
#                    production_company  ...  streaming_release_year  \
# 0                    20th Century Fox  ...                    2015
# 1              Sony Pictures Classics  ...                    2012
# 2                         Waner Bros.  ...                    2014
# 3                Criterion Collection  ...                    2017
# 4                              Disney  ...                    2016
# 5               Warner Bros. Pictures  ...                    2013
# 6        Gaumont British Distributors  ...                    2017
# 7                   Columbia Pictures  ...                    2012
# 8                 Excel Entertainment  ...                    2017
# 9                     New Video Group  ...                    2016
# 10                     United Artists  ...                    2013
# 11                   Toho Company Ltd  ...                    2017
# 12                 Paramount Pictures  ...                    2016
# 13                  Magnolia Pictures  ...                    2017
# 14                  Warner Home Video  ...                    2016
# 15             MGM Home Entertainment  ...                    2008
# 16                 Fine Line Features  ...                    2014
# 17                  VCI Entertainment  ...                    2016
# 18              Warner Bros. Pictures  ...                    2016
# 19           Eureka Entertainment Ltd  ...                    2017
# 20                      Miramax Flims  ...                    2016
# 21                       Warner Bros.  ...                    2014
# 22              Twentieth Century Fox  ...                    2014
# 23            LionsGate Entertainment  ...                    2018
# 24               Dolores Pictures LLC  ...                    2014
# 25                   20th Century Fox  ...                    2015
# 26                         Wellspring  ...                    2005
# 27                    New Line Cinema  ...                    2008
# 28                   Séville Pictures  ...                    2017
# 29                      Sony Pictures  ...                    2012
# 30                  Emerging Pictures  ...                    2016
# 31                                MGM  ...                    2016
# 32           Anchor Bay Entertainment  ...                    2017
# 33                   Regent Releasing  ...                    2016
# 34                                Fox  ...                    2012
# 35                  Warner Home Video  ...                    2012
# 37              Dark Forest Releasing  ...                    2016
# 38                         Wellspring  ...                    2006
# 39                                IDP  ...                    2017
# 42                 Batjac Productions  ...                    2016
# 44                     United Artists  ...                    2017
# 47                      Sony Pictures  ...                    2006
# 48                   Indican Pictures  ...                    2020
# 49                   20th Century Fox  ...                    2015
# 50                   IDP Distribution  ...                    2016
# 53                   Regent Releasing  ...                    2017
# 54                           SNP Inc.  ...                    2012
# 55                        Buena Vista  ...                    2016
# 57       Dreamland Motion Picture Co.  ...                    2012
# 58   Sony Pictures Home Entertainment  ...                    2013
# 63                            Miramax  ...                    2016
# 66                           Vivafilm  ...                    2017
# 67           Samuel Goldwyn Films LLC  ...                    2015
# 73           Anchor Bay Entertainment  ...                    2016
# 76                      Sony Classics  ...                    2012
# 81             Sony Pictures Classics  ...                    2014
# 82                   After Dark Films  ...                    2016
# 84                   The Cinema Guild  ...                    2015
# 87                Walt Disney Studios  ...                    2015
# 126  Sony Pictures Home Entertainment  ...                    2013
#
#      tomatometer_status  tomatometer_rating  tomatometer_count  \
# 0                Rotten                  49                149
# 1                 Fresh                  87                142
# 2                 Fresh                  67                 24
# 3                 Fresh                 100                 54
# 4                 Fresh                  89                 27
# 5                Rotten                   8                149
# 6                 Fresh                  96                 51
# 7                 Fresh                  96                 28
# 8                Rotten                  20                 10
# 9                 Fresh                  94                 18
# 10                Fresh                  82                 11
# 11                Fresh                  80                 15
# 12                Fresh                  91                 22
# 13               Rotten                  25                 83
# 14                Fresh                 100                 10
# 15                Fresh                  96                 28
# 16               Rotten                   4                 24
# 17                Fresh                 100                 18
# 18                Fresh                  69                124
# 19                Fresh                  80                  5
# 20                Fresh                  67                 52
# 21                Fresh                 100                 48
# 22                Fresh                  92                 12
# 23                Fresh                  75                  8
# 24               Rotten                   0                  6
# 25               Rotten                  31                121
# 26                Fresh                  63                 16
# 27               Rotten                  41                131
# 28               Rotten                   0                  5
# 29               Rotten                   8                 83
# 30                Fresh                  93                 15
# 31               Rotten                  22                 92
# 32               Rotten                  33                 18
# 33               Rotten                  21                 34
# 34               Rotten                   0                 12
# 35                Fresh                 100                 11
# 37               Rotten                  15                 13
# 38                Fresh                  87                 30
# 39                Fresh                  64                 69
# 42               Rotten                  52                 21
# 44               Rotten                   0                  8
# 47               Rotten                  44                 16
# 48                Fresh                  60                 10
# 49                Fresh                  97                 76
# 50               Rotten                  36                 14
# 53               Rotten                  30                 27
# 54               Rotten                  21                 28
# 55               Rotten                  10                 59
# 57                Fresh                  67                 15
# 58                Fresh                  95                 42
# 63                Fresh                  81                 59
# 66                Fresh                  78                  9
# 67                Fresh                  67                126
# 73                Fresh                  67                  9
# 76               Rotten                  58                125
# 81                Fresh                  69                 89
# 82                Fresh                 100                  8
# 84                Fresh                  88                 59
# 87               Rotten                  52                201
# 126               Fresh                  94                 49
#
#     audience_status  audience_rating  audience_count  \
# 0           Spilled               53          254421
# 1           Upright               64           11574
# 2           Spilled               53           14684
# 3           Upright               97          105386
# 4           Upright               74           68918
# 5           Spilled               37          411140
# 6           Upright               86           23890
# 7           Upright               79            9243
# 8           Upright               87            4819
# 9           Upright               80             486
# 10          Spilled               40             457
# 11          Upright               66           21475
# 12          Upright               79           20821
# 13          Upright               64           25944
# 14          Upright               86             335
# 15          Upright               86           10563
# 16          Spilled               35            1935
# 17          Upright               86             286
# 18          Spilled               57            6711
# 19          Upright               82            1046
# 20          Upright               80            4692
# 21          Upright               89           33946
# 22          Upright               75             554
# 23          Upright               60           10373
# 24          Upright               63             914
# 25          Upright               71          220956
# 26          Upright               80             867
# 27          Upright               79          135400
# 28          Upright               61           13033
# 29          Spilled               30          279994
# 30          Spilled               48             866
# 31          Spilled               56          134483
# 32          Upright               83            2622
# 33          Spilled               39            1295
# 34          Spilled               37            1460
# 35          Upright               88            1135
# 37          Upright               66            2059
# 38          Upright               73            9701
# 39          Upright               85            6203
# 42          Upright               63            7337
# 44          Spilled               42            5383
# 47          Upright               78           79542
# 48          Upright               67            1430
# 49          Upright               94          429674
# 50          Spilled               20            8239
# 53          Spilled               58            2394
# 54          Spilled               42            7326
# 55          Spilled               55          113424
# 57          Upright               65            5650
# 58          Upright               78            4866
# 63          Upright               80            1416
# 66          Upright               82           20404
# 67          Upright               85           54320
# 73          Upright               61           30371
# 76          Spilled               55           25860
# 81          Upright               79           10937
# 82          Spilled               43            4194
# 84          Upright               69            1333
# 87          Spilled               58          776189
# 126         Upright               61           11850
#
#     tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                              43                               73
# 1                              44                              123
# 2                               2                               16
# 3                               6                               54
# 4                               5                               24
# 5                              37                               12
# 6                               8                               49
# 7                               6                               27
# 8                               0                                2
# 9                               7                               17
# 10                              4                                9
# 11                              3                               12
# 12                              1                               20
# 13                             37                               21
# 14                              1                               10
# 15                              6                               27
# 16                             13                                1
# 17                              6                               18
# 18                             35                               85
# 19                              1                                4
# 20                             18                               35
# 21                              8                               48
# 22                              0                               11
# 23                              1                                6
# 24                              4                                0
# 25                             36                               38
# 26                              4                               10
# 27                             39                               54
# 28                              2                                0
# 29                             21                                7
# 30                              7                               14
# 31                             30                               20
# 32                              4                                6
# 33                             10                                7
# 34                              6                                0
# 35                              0                               11
# 37                              6                                2
# 38                             10                               26
# 39                             26                               44
# 42                              4                               11
# 44                              1                                0
# 47                              8                                7
# 48                              6                                6
# 49                             17                               74
# 50                              2                                5
# 53                             13                                8
# 54                             10                                6
# 55                             18                                6
# 57                              5                               10
# 58                              9                               40
# 63                             22                               48
# 66                              2                                7
# 67                             37                               85
# 73                              0                                6
# 76                             44                               72
# 81                             32                               61
# 82                              0                                8
# 84                             24                               52
# 87                             47                              105
# 126                            17                               46
#
#      tomatometer_rotten_critics_count
# 0                                  76
# 1                                  19
# 2                                   8
# 3                                   0
# 4                                   3
# 5                                 137
# 6                                   2
# 7                                   1
# 8                                   8
# 9                                   1
# 10                                  2
# 11                                  3
# 12                                  2
# 13                                 62
# 14                                  0
# 15                                  1
# 16                                 23
# 17                                  0
# 18                                 39
# 19                                  1
# 20                                 17
# 21                                  0
# 22                                  1
# 23                                  2
# 24                                  6
# 25                                 83
# 26                                  6
# 27                                 77
# 28                                  5
# 29                                 76
# 30                                  1
# 31                                 72
# 32                                 12
# 33                                 27
# 34                                 12
# 35                                  0
# 37                                 11
# 38                                  4
# 39                                 25
# 42                                 10
# 44                                  8
# 47                                  9
# 48                                  4
# 49                                  2
# 50                                  9
# 53                                 19
# 54                                 22
# 55                                 53
# 57                                  5
# 58                                  2
# 63                                 11
# 66                                  2
# 67                                 41
# 73                                  3
# 76                                 53
# 81                                 28
# 82                                  0
# 84                                  7
# 87                                 96
# 126                                 3
#
# [60 rows x 23 columns]

# %%
#create moviemonth dataframe
jan_movie = moviedf[(moviedf["release_month"] == 1)]
feb_movie = moviedf[(moviedf["release_month"] == 2)]
mar_movie = moviedf[(moviedf["release_month"] == 3)]
apr_movie = moviedf[(moviedf["release_month"] == 4)]
may_movie = moviedf[(moviedf["release_month"] == 5)]
jun_movie = moviedf[(moviedf["release_month"] == 6)]
jul_movie = moviedf[(moviedf["release_month"] == 7)]
aug_movie = moviedf[(moviedf["release_month"] == 8)]
sep_movie = moviedf[(moviedf["release_month"] == 9)]
oct_movie = moviedf[(moviedf["release_month"] == 10)]
nov_movie = moviedf[(moviedf["release_month"] == 11)]
dec_movie = moviedf[(moviedf["release_month"] == 12)]
jan_movie.head()
# Out:
#                      rotten_tomatoes_link  \
# 4   m/1000079-20000_leagues_under_the_sea
# 11                  m/10002114-dark_water
# 22                    m/10003876-man_hunt
# 25          m/10004209-tristan_and_isolde
# 31                      m/10004659-arthur
#
#                                           movie_title  \
# 4                        20,000 Leagues Under The Sea
# 11                                         Dark Water
# 22                                           Man Hunt
# 25                                   Tristan & Isolde
# 31  Arthur and the Invisibles (Arthur and the Mini...
#
#                                            movie_info content_rating  \
# 4   In 1866, Professor Pierre M. Aronnax (Paul Luk...              G
# 11  In this moody Japanese horror film, newly-sing...          PG-13
# 22  Renowned big-game hunter Captain Thorndike (Wa...             NR
# 25  After the fall of the Roman Empire, English or...          PG-13
# 31  Ten-year-old Arthur must find a way to keep th...             PG
#
#                                                genres          directors  \
# 4            Action & Adventure, Drama, Kids & Family  Richard Fleischer
# 11  Art House & International, Horror, Mystery & S...       Hideo Nakata
# 22                Classics, Drama, Mystery & Suspense         Fritz Lang
# 25          Drama, Science Fiction & Fantasy, Romance     Kevin Reynolds
# 31  Animation, Kids & Family, Science Fiction & Fa...         Luc Besson
#
#                                               authors  \
# 4                                         Earl Felton
# 11  Hideo Hakata, Takashige Ichise, Yoshihiro Naka...
# 22                                     Dudley Nichols
# 25                                     Dean Georgaris
# 31                          Luc Besson, Celine Garcia
#
#                                                actors  runtime  \
# 4   James Mason, Kirk Douglas, Paul Lukas, Peter L...      127
# 11  Hitomi Kuroki, Rio Kanno, Shigemitsu Ogi, Mire...      100
# 22  Walter Pidgeon, Joan Bennett, George Sanders, ...      100
# 25  James Franco, Sophia Myles, Rufus Sewell, Davi...      126
# 31  Freddie Highmore, Mia Farrow, Penny Balfour, D...       94
#
#        production_company  ...  streaming_release_year  tomatometer_status  \
# 4                  Disney  ...                    2016               Fresh
# 11       Toho Company Ltd  ...                    2017               Fresh
# 22  Twentieth Century Fox  ...                    2014               Fresh
# 25       20th Century Fox  ...                    2015              Rotten
# 31                    MGM  ...                    2016              Rotten
#
#     tomatometer_rating  tomatometer_count audience_status  audience_rating  \
# 4                   89                 27         Upright               74
# 11                  80                 15         Upright               66
# 22                  92                 12         Upright               75
# 25                  31                121         Upright               71
# 31                  22                 92         Spilled               56
#
#     audience_count tomatometer_top_critics_count  \
# 4            68918                             5
# 11           21475                             3
# 22             554                             0
# 25          220956                            36
# 31          134483                            30
#
#     tomatometer_fresh_critics_count  tomatometer_rotten_critics_count
# 4                                24                                 3
# 11                               12                                 3
# 22                               11                                 1
# 25                               38                                83
# 31                               20                                72
#
# [5 rows x 23 columns]

# %%
#group datafram by month and find average rotten tomato score
jan_score = jan_movie.mean()["tomatometer_rating"]
feb_score = feb_movie.mean()["tomatometer_rating"]
mar_score = mar_movie.mean()["tomatometer_rating"]
apr_score = apr_movie.mean()["tomatometer_rating"]
may_score = may_movie.mean()["tomatometer_rating"]
jun_score = jun_movie.mean()["tomatometer_rating"]
jul_score = jul_movie.mean()["tomatometer_rating"]
aug_score = aug_movie.mean()["tomatometer_rating"]
sep_score = sep_movie.mean()["tomatometer_rating"]
oct_score = oct_movie.mean()["tomatometer_rating"]
nov_score = nov_movie.mean()["tomatometer_rating"]
dec_score = dec_movie.mean()["tomatometer_rating"]
# Out:
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   import sys
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if __name__ == '__main__':
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if sys.path[0] == '':
# C:\Users\prisc\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   del sys.path[0]

# %%
avg_rat_per_month= {'Month':['Jan','Feb', 'Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                   'Rotten_Tomato_Score': [jan_score, feb_score, mar_score, apr_score, may_score, jun_score, jul_score, aug_score, sep_score, oct_score, nov_score, dec_score]}
avg_rat_per_month_df=pd.DataFrame(avg_rat_per_month)
avg_rat_per_month_df.head(12)
# Out:
#    Month  Rotten_Tomato_Score
# 0    Jan            60.907673
# 1    Feb            55.671941
# 2    Mar            57.699571
# 3    Apr            55.765009
# 4    May            59.431018
# 5    Jun            59.438744
# 6    Jul            59.151295
# 7    Aug            57.239583
# 8    Sep            57.809710
# 9    Oct            58.348803
# 10   Nov            62.167587
# 11   Dec            62.012872

# %%
#Set bar chart axis
x_axis = avg_rat_per_month_df["Month"]
y_axis = avg_rat_per_month_df["Rotten_Tomato_Score"]
col = []
label= ["Rotten", "Fresh"]
for lab in label:
    if lab == "Rotten":
        color = 'green'
    else:
        color= 'red'
for val in y_axis:
    if val < 60:
        col.append('green')
    else:
        col.append('red')
plt.bar(x_axis, y_axis, color = col, label = 'Fresh' la)
plt.xlabel("Month")
plt.ylabel("Rotten Tomato Score")
plt.title("Average Tomatometer Status by Month")
plt.ylim(50,70)
plt.legend()

# %%
#make list where audience and critic scores align
critics_audience_agree=[]
critic_score= moviedf['tomatometer_status']
audience_score= moviedf['audience_status']

# %%
critic_score_val=[]
audience_score_val=[]
for i in critic_score:
    if i == 'Fresh':
        critic_score_val.append(1)
    else:
        critic_score_val.append(0)
for i in audience_score:
    if i == 'Upright':
        audience_score_val.append(1)
    else:
        audience_score_val.append(0)

# %%
moviedf["critic_score_val"]= critic_score_val
moviedf["audience_score_val"]=audience_score_val
moviedf.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info content_rating  \
# 0  Always trouble-prone, the life of teenager Per...             PG
# 1  Kate (Catherine Keener) and her husband Alex (...              R
# 2  A successful, middle-aged Hollywood songwriter...              R
# 3  Following the closing arguments in a murder tr...             NR
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors  runtime  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...      119
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...       90
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...      122
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....       95
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...      127
#
#        production_company  ...  tomatometer_rating  tomatometer_count  \
# 0        20th Century Fox  ...                  49                149
# 1  Sony Pictures Classics  ...                  87                142
# 2             Waner Bros.  ...                  67                 24
# 3    Criterion Collection  ...                 100                 54
# 4                  Disney  ...                  89                 27
#
#    audience_status  audience_rating audience_count  \
# 0          Spilled               53         254421
# 1          Upright               64          11574
# 2          Spilled               53          14684
# 3          Upright               97         105386
# 4          Upright               74          68918
#
#    tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                             43                               73
# 1                             44                              123
# 2                              2                               16
# 3                              6                               54
# 4                              5                               24
#
#   tomatometer_rotten_critics_count  critic_score_val  audience_score_val
# 0                               76                 0                   0
# 1                               19                 1                   1
# 2                                8                 1                   0
# 3                                0                 1                   1
# 4                                3                 1                   1
#
# [5 rows x 25 columns]

# %%
#define conditions
conditions =[((moviedf['critic_score_val']==1) & (moviedf['audience_score_val']==1)), 
             ((moviedf['critic_score_val']==1) & (moviedf['audience_score_val']==0)),
             ((moviedf['critic_score_val']==0) & (moviedf['audience_score_val']==1)),
             ((moviedf['critic_score_val']==0) & (moviedf['audience_score_val']==0))]

#define choices
choices = ['Yes', 'No','No','Yes']

#create new column in DataFrame that displays results of comparisons
moviedf['critics_audience_agree'] = np.select(conditions, choices)

moviedf.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info content_rating  \
# 0  Always trouble-prone, the life of teenager Per...             PG
# 1  Kate (Catherine Keener) and her husband Alex (...              R
# 2  A successful, middle-aged Hollywood songwriter...              R
# 3  Following the closing arguments in a murder tr...             NR
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors  runtime  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...      119
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...       90
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...      122
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....       95
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...      127
#
#        production_company  ...  tomatometer_count  audience_status  \
# 0        20th Century Fox  ...                149          Spilled
# 1  Sony Pictures Classics  ...                142          Upright
# 2             Waner Bros.  ...                 24          Spilled
# 3    Criterion Collection  ...                 54          Upright
# 4                  Disney  ...                 27          Upright
#
#    audience_rating  audience_count tomatometer_top_critics_count  \
# 0               53          254421                            43
# 1               64           11574                            44
# 2               53           14684                             2
# 3               97          105386                             6
# 4               74           68918                             5
#
#    tomatometer_fresh_critics_count  tomatometer_rotten_critics_count  \
# 0                               73                                76
# 1                              123                                19
# 2                               16                                 8
# 3                               54                                 0
# 4                               24                                 3
#
#   critic_score_val  audience_score_val  critics_audience_agree
# 0                0                   0                     Yes
# 1                1                   1                     Yes
# 2                1                   0                      No
# 3                1                   1                     Yes
# 4                1                   1                     Yes
#
# [5 rows x 26 columns]

# %%
moviedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              14437 non-null  object
#  1   movie_title                       14437 non-null  object
#  2   movie_info                        14437 non-null  object
#  3   content_rating                    14437 non-null  object
#  4   genres                            14437 non-null  object
#  5   directors                         14437 non-null  object
#  6   authors                           14437 non-null  object
#  7   actors                            14437 non-null  object
#  8   runtime                           14437 non-null  int64
#  9   production_company                14437 non-null  object
#  10  release_month                     14437 non-null  int64
#  11  streaming_month                   14437 non-null  int64
#  12  release_year                      14437 non-null  int64
#  13  streaming_release_year            14437 non-null  int64
#  14  tomatometer_status                14437 non-null  object
#  15  tomatometer_rating                14437 non-null  int64
#  16  tomatometer_count                 14437 non-null  int64
#  17  audience_status                   14437 non-null  object
#  18  audience_rating                   14437 non-null  int64
#  19  audience_count                    14437 non-null  int64
#  20  tomatometer_top_critics_count     14437 non-null  int64
#  21  tomatometer_fresh_critics_count   14437 non-null  int64
#  22  tomatometer_rotten_critics_count  14437 non-null  int64
#  23  critic_score_val                  14437 non-null  int64
#  24  audience_score_val                14437 non-null  int64
#  25  critics_audience_agree            14437 non-null  object
# dtypes: int64(14), object(12)
# memory usage: 2.9+ MB

# %%
#find count of yes and no agrees
critics_agree=moviedf[moviedf['critics_audience_agree']=='Yes'].critics_audience_agree.count()
critics_disagree=moviedf[moviedf['critics_audience_agree']=='No'].critics_audience_agree.count()

# %%
#create pie chart
y_axis=[critics_agree, critics_disagree]
x_axis=["Audience Agree", "Audience Disagree"]
explode = (.2,0)
colors = ("yellowgreen", "gold")
plt.pie(y_axis, explode=explode, labels= x_axis, autopct='%.1f%%', colors=colors, wedgeprops={"edgecolor":"0",'linewidth': 1,
                    'linestyle': 'solid', 'antialiased': True})
plt.title("Percentage Critic Review Aligns\n" + "With Audience Review", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %%
#arrange df in descending order
cols=moviedf.tomatometer_rating .tolist()
cols.sort()

sorted_df=moviedf.sort_values(by =['tomatometer_rating','audience_rating'], ascending=False)

#get top movies
top_movies= pd.DataFrame(sorted_df.head(10))
top_movies_score=top_movies[["tomatometer_rating","audience_rating"]]
top_movies_score


#get bottom movies
bottom_sorted_df=moviedf.sort_values(by =['tomatometer_rating','audience_rating'])
bot_movies= pd.DataFrame(bottom_sorted_df.head(10))
bot_movies_score=bot_movies[["tomatometer_rating","audience_rating"]]

# %%
#display top and bottom dfs
top_movies
# Out:
#                       rotten_tomatoes_link  \
# 8119                m/lost_in_america_2020
# 12685                   m/the_miners_hymns
# 13051                    m/the_uncondemned
# 7575                         m/maktub_2018
# 7368   m/jump_shot_the_kenny_sailors_story
# 3                   m/1000013-12_angry_men
# 6297                            m/harakiri
# 8406                        m/marlene_1984
# 10795                 m/seven_samurai_1956
# 14109             m/white_light_black_rain
#
#                                              movie_title  \
# 8119                                     Lost in America
# 12685                                  The Miners' Hymns
# 13051                                    The Uncondemned
# 7575                                              Maktub
# 7368                  Jump Shot: The Kenny Sailors Story
# 3                        12 Angry Men (Twelve Angry Men)
# 6297                                            Harakiri
# 8406                                             Marlene
# 10795               Seven Samurai (Shichinin no Samurai)
# 14109  White Light/Black Rain: The Destruction of Hir...
#
#                                               movie_info content_rating  \
# 8119   Chronicles homelessness in the United States f...             NR
# 12685  Bill Morrison creates a portrait of a vanished...             NR
# 13051  An underdog group of lawyers and activists def...             NR
# 7575   After surviving a restaurant bombing in Jerusa...             NR
# 7368   Kenny Sailors popularizes the jump shot in pro...             NR
# 3      Following the closing arguments in a murder tr...             NR
# 6297   Aging samurai Hanshiro Tsugumo (Tatsuya Nakada...              G
# 8406   Directed by German actor Maximilian Schell, th...             NR
# 10795  A samurai answers a village's request for prot...              G
# 14109  Using extensive interviews with survivors and ...             NR
#
#                                                   genres  \
# 8119                                         Documentary
# 12685               Documentary, Drama, Special Interest
# 13051                                        Documentary
# 7575            Art House & International, Comedy, Drama
# 7368                                         Documentary
# 3                                        Classics, Drama
# 6297          Art House & International, Classics, Drama
# 8406                       Documentary, Special Interest
# 10795  Action & Adventure, Art House & International,...
# 14109                      Documentary, Special Interest
#
#                            directors  \
# 8119                Rotimi Rainwater
# 12685             Bill Morrison (II)
# 13051  Nick Louvel, Michele Mitchell
# 7575                        Oded Raz
# 7368                  Jacob Hamilton
# 3                       Sidney Lumet
# 6297                Masaki Kobayashi
# 8406               Maximilian Schell
# 10795                 Akira Kurosawa
# 14109                 Steven Okazaki
#
#                                               authors  \
# 8119                                 Rotimi Rainwater
# 12685              David Metcalfe, Bill Morrison (II)
# 13051                                Michele Mitchell
# 7575                           Guy Amir, Hanan Savyon
# 7368                                   Jacob Hamilton
# 3                                       Reginald Rose
# 6297                                Shinobu Hashimoto
# 8406                   Meir Dohnal, Maximilian Schell
# 10795  Akira Kurosawa, Shinobu Hashimoto, Hideo Oguni
# 14109                                  Steven Okazaki
#
#                                                   actors  runtime  \
# 8119   Halle Berry, Jewel Kilcher, Jon Bon Jovi, Rosa...       94
# 12685  Eric Leckenby, Brian Gibson, Alex Trotter, Joh...       52
# 13051  Sara Darehshori, Patricia Sellers, Pierre-Rich...       81
# 7575   Guy Amir, Hanan Savyon, Gal Amitai, Chen Amsal...      100
# 7368   Bobby Knight, Dirk Nowitzki, Kevin Durant, Ste...       73
# 3      Martin Balsam, John Fiedler, Lee J. Cobb, E.G....       95
# 6297   Shima Iwashita, Tatsuya Nakadai, Akira Ishiham...      135
# 8406   Maximilian Schell, Marlene Dietrich, Karel Dir...       95
# 10795  Toshiro Mifune, Takashi Shimura, Yoshio Inaba,...      208
# 14109  Yasuyo Tanaka, Chiemi Oka, Sakue Shimohira, Ka...       85
#
#              production_company  ...  tomatometer_count  audience_status  \
# 8119           Indican Pictures  ...                  7          Upright
# 12685              Icarus Films  ...                 10          Upright
# 13051            Film at Eleven  ...                 13          Upright
# 7575                Firma Films  ...                  5          Upright
# 7368   Aspiration Entertainment  ...                 14          Upright
# 3          Criterion Collection  ...                 54          Upright
# 6297       Criterion Collection  ...                  8          Upright
# 8406       Nelson Entertainment  ...                  7          Upright
# 10795         Columbia Pictures  ...                 65          Upright
# 14109                       HBO  ...                  6          Upright
#
#        audience_rating  audience_count tomatometer_top_critics_count  \
# 8119               100              11                             5
# 12685              100             148                             5
# 13051              100             124                             6
# 7575                99             401                             1
# 7368                98             103                             1
# 3                   97          105386                             6
# 6297                97            5960                             2
# 8406                97             227                             2
# 10795               97           91013                            12
# 14109               96             933                             3
#
#        tomatometer_fresh_critics_count  tomatometer_rotten_critics_count  \
# 8119                                 7                                 0
# 12685                               10                                 0
# 13051                               13                                 0
# 7575                                 5                                 0
# 7368                                14                                 0
# 3                                   54                                 0
# 6297                                 8                                 0
# 8406                                 7                                 0
# 10795                               65                                 0
# 14109                                6                                 0
#
#       critic_score_val  audience_score_val  critics_audience_agree
# 8119                 1                   1                     Yes
# 12685                1                   1                     Yes
# 13051                1                   1                     Yes
# 7575                 1                   1                     Yes
# 7368                 1                   1                     Yes
# 3                    1                   1                     Yes
# 6297                 1                   1                     Yes
# 8406                 1                   1                     Yes
# 10795                1                   1                     Yes
# 14109                1                   1                     Yes
#
# [10 rows x 26 columns]

# %%
size=[500, 450 , 400, 350, 300, 250, 200, 150, 100, 50]
x=top_movies["movie_title"]
y=top_movies["runtime"]
plt.scatter(x,y, marker="*", s=size, color="red")
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")
plt.grid()

# %%
size=[500, 450 , 400, 350, 300, 250, 200, 150, 100, 50]
x=bot_movies["movie_title"]
y=bot_movies["runtime"]
plt.scatter(x,y, marker="*", s=size, c="green")
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")
plt.grid()

# %%
x=top_movies["movie_title"]
y=top_movies["runtime"]
plt.bar(x,y, color="red")
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")
plt.grid()

# %%
x=bot_movies["movie_title"]
y=bot_movies["runtime"]
plt.bar(x,y, color="green")
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")
plt.grid()

# %%
x=top_movies["content_rating"]
y=top_movies["runtime"]
plt.scatter(x,y, color="red")
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")
plt.grid()

# %%
from random import randint

color = ["gold", "red", "orange", "purple", "blue", "yellow", "yellowgreen", "green", "brown", "black"]

# %%
size=[500, 450 , 400, 350, 300, 250, 200, 150, 100, 50]
x=bot_movies["movie_title"]
label= bot_movies["movie_title"].tolist()
y=bot_movies["runtime"]
plt.scatter(x,y, marker="*", s=size, c=color)
plt.xticks(rotation=85)
plt.xlabel("Movie Title")
plt.ylabel("Runtime")

plt.legend(loc="right")
plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#create dataframes from runtime and tomatostatus
rotten_df=moviedf[moviedf["tomatometer_status"] == "Rotten"]
fresh_df=moviedf[moviedf["tomatometer_status"] == "Fresh"]
rotten_runtime=rotten_df["runtime"].unique()
fresh_runtime=fresh_df["runtime"].unique()

# %%
# Create a box-and-whisker plot for the rntime
x_labels = ["Rotten", "Fresh"]
tomatometer_data= [rotten_runtime, fresh_runtime]
fig, ax = plt.subplots()
ax.boxplot(tomatometer_data, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Movie Runtime for Rated Films')
ax.set_ylabel('Runtime')
ax.set_yticks(np.arange(0, 300, step=25))
ax.set_xlabel('Tomatometer Status')
ax.grid()
plt.show()

# %%
#find how many release years in dataframe
movie_years=moviedf["release_year"].unique()

# %%
movie_years
# Out:
# array([2010, 1979, 1957, 1954, 2008, 1935, 2002, 2012, 1930, 1988, 2005,
#        1950, 1949, 1951, 2004, 1985, 1938, 1941, 2003, 2006, 2007, 1952,
#        1960, 1956, 1966, 1986, 1984, 2009, 1973, 2014, 2011, 1990, 1947,
#        1987, 1940, 1981, 1976, 1958, 1980, 1961, 1972, 1946, 2015, 1962,
#        1963, 1974, 1926, 1977, 1929, 1944, 1982, 1968, 1978, 1983, 1970,
#        1945, 1919, 1975, 1955, 1969, 1953, 1967, 1936, 1937, 1942, 1927,
#        1989, 1931, 1965, 2016, 1971, 1964, 1933, 1939, 2001, 1959, 1948,
#        1992, 2013, 2000, 2017, 1923, 1916, 1993, 1921, 1934, 1920, 1932,
#        1925, 2019, 1943, 2018, 1991, 1928, 1995, 1999, 1994, 1998, 1996,
#        1997, 2020, 1915, 1922, 1914, 1924], dtype=int64)

# %%
#separate years into separate dataframes based on year
two_thousands = moviedf[moviedf['release_year'].between(2000, 2010)]
two_thousands_tens= moviedf[moviedf['release_year'].between(2011, 2020)]
nineties=moviedf[moviedf['release_year'].between(1990, 1999)]
eights=moviedf[moviedf['release_year'].between(1980, 1989)]
seventies=moviedf[moviedf['release_year'].between(1970, 1979)]
sixties=moviedf[moviedf['release_year'].between(1960, 1969)]
fifties=moviedf[moviedf['release_year'].between(1950, 1959)]
before_50s=moviedf[moviedf['release_year'].between(1900, 1949)]
print( two_thousands.count())
print(two_thousands_tens.count())
print(nineties.count())
print(eights.count())
print(seventies.count())
print(sixties.count())
print(fifties.count())
print(before_50s.count())
# Out:
# rotten_tomatoes_link                4195
# movie_title                         4195
# movie_info                          4195
# content_rating                      4195
# genres                              4195
# directors                           4195
# authors                             4195
# actors                              4195
# runtime                             4195
# production_company                  4195
# release_month                       4195
# streaming_month                     4195
# release_year                        4195
# streaming_release_year              4195
# tomatometer_status                  4195
# tomatometer_rating                  4195
# tomatometer_count                   4195
# audience_status                     4195
# audience_rating                     4195
# audience_count                      4195
# tomatometer_top_critics_count       4195
# tomatometer_fresh_critics_count     4195
# tomatometer_rotten_critics_count    4195
# critic_score_val                    4195
# audience_score_val                  4195
# critics_audience_agree              4195
# dtype: int64
# rotten_tomatoes_link                4971
# movie_title                         4971
# movie_info                          4971
# content_rating                      4971
# genres                              4971
# directors                           4971
# authors                             4971
# actors                              4971
# runtime                             4971
# production_company                  4971
# release_month                       4971
# streaming_month                     4971
# release_year                        4971
# streaming_release_year              4971
# tomatometer_status                  4971
# tomatometer_rating                  4971
# tomatometer_count                   4971
# audience_status                     4971
# audience_rating                     4971
# audience_count                      4971
# tomatometer_top_critics_count       4971
# tomatometer_fresh_critics_count     4971
# tomatometer_rotten_critics_count    4971
# critic_score_val                    4971
# audience_score_val                  4971
# critics_audience_agree              4971
# dtype: int64
# rotten_tomatoes_link                1918
# movie_title                         1918
# movie_info                          1918
# content_rating                      1918
# genres                              1918
# directors                           1918
# authors                             1918
# actors                              1918
# runtime                             1918
# production_company                  1918
# release_month                       1918
# streaming_month                     1918
# release_year                        1918
# streaming_release_year              1918
# tomatometer_status                  1918
# tomatometer_rating                  1918
# tomatometer_count                   1918
# audience_status                     1918
# audience_rating                     1918
# audience_count                      1918
# tomatometer_top_critics_count       1918
# tomatometer_fresh_critics_count     1918
# tomatometer_rotten_critics_count    1918
# critic_score_val                    1918
# audience_score_val                  1918
# critics_audience_agree              1918
# dtype: int64
# rotten_tomatoes_link                1136
# movie_title                         1136
# movie_info                          1136
# content_rating                      1136
# genres                              1136
# directors                           1136
# authors                             1136
# actors                              1136
# runtime                             1136
# production_company                  1136
# release_month                       1136
# streaming_month                     1136
# release_year                        1136
# streaming_release_year              1136
# tomatometer_status                  1136
# tomatometer_rating                  1136
# tomatometer_count                   1136
# audience_status                     1136
# audience_rating                     1136
# audience_count                      1136
# tomatometer_top_critics_count       1136
# tomatometer_fresh_critics_count     1136
# tomatometer_rotten_critics_count    1136
# critic_score_val                    1136
# audience_score_val                  1136
# critics_audience_agree              1136
# dtype: int64
# rotten_tomatoes_link                657
# movie_title                         657
# movie_info                          657
# content_rating                      657
# genres                              657
# directors                           657
# authors                             657
# actors                              657
# runtime                             657
# production_company                  657
# release_month                       657
# streaming_month                     657
# release_year                        657
# streaming_release_year              657
# tomatometer_status                  657
# tomatometer_rating                  657
# tomatometer_count                   657
# audience_status                     657
# audience_rating                     657
# audience_count                      657
# tomatometer_top_critics_count       657
# tomatometer_fresh_critics_count     657
# tomatometer_rotten_critics_count    657
# critic_score_val                    657
# audience_score_val                  657
# critics_audience_agree              657
# dtype: int64
# rotten_tomatoes_link                554
# movie_title                         554
# movie_info                          554
# content_rating                      554
# genres                              554
# directors                           554
# authors                             554
# actors                              554
# runtime                             554
# production_company                  554
# release_month                       554
# streaming_month                     554
# release_year                        554
# streaming_release_year              554
# tomatometer_status                  554
# tomatometer_rating                  554
# tomatometer_count                   554
# audience_status                     554
# audience_rating                     554
# audience_count                      554
# tomatometer_top_critics_count       554
# tomatometer_fresh_critics_count     554
# tomatometer_rotten_critics_count    554
# critic_score_val                    554
# audience_score_val                  554
# critics_audience_agree              554
# dtype: int64
# rotten_tomatoes_link                429
# movie_title                         429
# movie_info                          429
# content_rating                      429
# genres                              429
# directors                           429
# authors                             429
# actors                              429
# runtime                             429
# production_company                  429
# release_month                       429
# streaming_month                     429
# release_year                        429
# streaming_release_year              429
# tomatometer_status                  429
# tomatometer_rating                  429
# tomatometer_count                   429
# audience_status                     429
# audience_rating                     429
# audience_count                      429
# tomatometer_top_critics_count       429
# tomatometer_fresh_critics_count     429
# tomatometer_rotten_critics_count    429
# critic_score_val                    429
# audience_score_val                  429
# critics_audience_agree              429
# dtype: int64
# rotten_tomatoes_link                577
# movie_title                         577
# movie_info                          577
# content_rating                      577
# genres                              577
# directors                           577
# authors                             577
# actors                              577
# runtime                             577
# production_company                  577
# release_month                       577
# streaming_month                     577
# release_year                        577
# streaming_release_year              577
# tomatometer_status                  577
# tomatometer_rating                  577
# tomatometer_count                   577
# audience_status                     577
# audience_rating                     577
# audience_count                      577
# tomatometer_top_critics_count       577
# tomatometer_fresh_critics_count     577
# tomatometer_rotten_critics_count    577
# critic_score_val                    577
# audience_score_val                  577
# critics_audience_agree              577
# dtype: int64

# %%
#find avaerage tomatometer status per years
two_thousands_avg = two_thousands["tomatometer_rating"].mean()
two_thousands_tens_avg= two_thousands_tens["tomatometer_rating"].mean()
nineties_avg=nineties["tomatometer_rating"].mean()
eights_avg=eights["tomatometer_rating"].mean()
seventies_avg=seventies["tomatometer_rating"].mean()
sixties_avg=sixties["tomatometer_rating"].mean()
fifties_avg=fifties["tomatometer_rating"].mean()
before_50s_avg=before_50s["tomatometer_rating"].mean()

# %%
#set x and y axis
x= ["Before 50s", "50's", "60's", "70's", "80's", "90's", "2000's", "2010's"]
y= [before_50s_avg, fifties_avg, sixties_avg, seventies_avg, eights_avg, nineties_avg, two_thousands_avg, two_thousands_tens_avg ]
plt.plot(x,y, label="Tomatometer Rating", marker="*", markerfacecolor="black", markersize=15, color= "gold", linewidth=3)
plt.xlabel("Decade")
plt.ylabel("Tomatometer Rating")
plt.grid()
plt.title("Tomatometer Rating Through the Decades")
plt.legend()

# %%
#separate years into separate dataframes based on year
two_thousands = moviedf[moviedf['release_year'].between(2000, 2010)]
two_thousands_tens= moviedf[moviedf['release_year'].between(2011, 2020)]
ninteen_hundreds= moviedf[moviedf['release_year'].between(1900, 1999)]

# %%
#find avaerage tomatometer status per years
two_thousands_avg = two_thousands["tomatometer_rating"].mean()
two_thousands_tens_avg= two_thousands_tens["tomatometer_rating"].mean()
ninteen_avg= ninteen_hundreds["tomatometer_rating"].mean()

# %%
#set x and y axis
x= ["1900's", "2000's", "2010's"]
y= [ninteen_avg, two_thousands_avg, two_thousands_tens_avg ]
plt.plot(x,y, label="Tomatometer Rating", marker="*", markerfacecolor="black", markersize=15, color= "gold", linewidth=3)
plt.xlabel("Year")
plt.ylabel("Tomatometer Rating")
plt.grid()
plt.title("Tomatometer Rating Through the Years")
plt.legend()
